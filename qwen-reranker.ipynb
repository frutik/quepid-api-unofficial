# %% [markdown]
# # Testing Qwen3 reranker on WANDS

# %% [markdown]
# ## Objective
#
# In this project, the goal is to:
#
# - Set up a local Quepid instance - giving us a safe playground for experimentation.
# - Programmatically load the WANDS dataset into Quepid - creating multiple cases from the same dataset to test different configurations and scenarios.
# - Compare scoring approaches - evaluate and contrast various methods for measuring search quality across those cases.
#
# By the end, we’ll have a reproducible workflow for running relevance experiments locally and benchmarking scoring strategies using the WANDS dataset.

# %% [markdown]
# ## What is WANDS
#
# WANDS is a human-annotated dataset from Wayfair for evaluating product search relevance. It includes 480 queries, ~43K products, and 233K query-product relevance labels (Exact, Partial, Irrelevant), plus rich product metadata—ideal for training and benchmarking search models.

# %% [markdown]
# ## What is Quepid
#
# Quepid is an open-source search relevance tuning and evaluation tool that bridges the gap between search engineers and domain experts. It lets you run queries, inspect results, and score them against a gold standard of relevance judgments — all in a collaborative interface. With support for search engines like Elasticsearch, Solr, and OpenSearch, Quepid makes it easier to experiment with ranking changes, track their impact over time, and communicate improvements to non-technical stakeholders. Whether you’re iterating on query configurations or benchmarking machine-learning-based ranking models, Quepid gives you a structured way to measure and improve search quality.

# %% [markdown]
# ## Initial set up of everything

# %% [markdown]
# #### Set Up Infra

# %% [markdown]
# `cp .env.example .env`
#
# `vi .env`

# %%
# !docker compose -f docker-compose.yml -f docker-compose-reranker.yml build
# Out:
# [+] Building 0.0s (0/1)
#  => [internal] load local bake definitions                                 0.0s
# [+] Building 0.2s (1/1)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.30kB                                           0.0s
# [+] Building 0.2s (2/2)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.30kB                                           0.0s
#  => [quepid-api-app internal] load build definition from Dockerfile        0.0s
# [+] Building 0.3s (2/4)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.30kB                                           0.0s
#  => [quepid-api-app internal] load build definition from Dockerfile        0.0s
#  => => transferring dockerfile: 1.07kB                                     0.0s
#  => [quepid-api-app internal] load metadata for docker.io/library/python:  0.2s
#  => [quepid-api-web internal] load metadata for docker.io/library/nginx:m  0.2s
# [+] Building 0.4s (2/4)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.30kB                                           0.0s
#  => [quepid-api-app internal] load build definition from Dockerfile        0.0s
#  => => transferring dockerfile: 1.07kB                                     0.0s
#  => [quepid-api-app internal] load metadata for docker.io/library/python:  0.2s
#  => [quepid-api-web internal] load metadata for docker.io/library/nginx:m  0.2s
# [+] Building 0.5s (25/26)
#  => CACHED [quepid-api-web app 10/13] COPY . ./                            0.0s
#  => CACHED [quepid-api-web app 11/13] RUN ./manage.py collectstatic --noi  0.0s
#  => CACHED [quepid-api-web app 12/13] RUN chown -R www-data:www-data .     0.0s
#  => CACHED [quepid-api-web app 13/13] RUN ln -snf /usr/share/zoneinfo/Eur  0.0s
#  => CACHED [quepid-api-web web 2/4] RUN apk add --no-cache tzdata          0.0s
#  => CACHED [quepid-api-web web 3/4] COPY --from=app /app/static /usr/shar  0.0s
#  => CACHED [quepid-api-web web 4/4] COPY docker/nginx.conf /etc/nginx/con  0.0s
#  => [quepid-api-web] exporting to image                                    0.0s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:c3d1afecde3f3e648f47b6a7b170670f4f025241  0.0s
#  => => exporting config sha256:7e05132cf6a698417480a28215e8c2295a278b1d88  0.0s
#  => => exporting attestation manifest sha256:1ab915bf1ad7d58c24c6b160c88c  0.0s
#  => => exporting manifest list sha256:31d6c84eaf1bedb9064e71ba25ff45b7b57  0.0s
#  => => naming to docker.io/frutik777/quepid-api-unofficial-web:latest      0.0s
#  => [quepid-api-app] exporting to image                                    0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:cbf6f19f9f838be6916f250b86aae276e7738f77  0.0s
#  => => exporting config sha256:5d995d9f5fe936792d7256dee0bba83ce241134d93  0.0s
#  => => exporting attestation manifest sha256:02c76f6e0efe6d578b5794af274b  0.0s
#  => => exporting manifest list sha256:b9b4b3c2030879be5c300e5bbb2574e1346  0.0s
#  => => naming to docker.io/frutik777/quepid-api-unofficial:latest          0.0s
#  => [quepid-api-web] resolving provenance for metadata file                0.0s
# [+] Building 0.5s (27/27) FINISHED
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 1.30kB                                           0.0s
#  => [quepid-api-app internal] load build definition from Dockerfile        0.0s
#  => => transferring dockerfile: 1.07kB                                     0.0s
#  => [quepid-api-web internal] load metadata for docker.io/library/python:  0.2s
#  => [quepid-api-web internal] load metadata for docker.io/library/nginx:m  0.2s
#  => [quepid-api-web internal] load .dockerignore                           0.0s
#  => => transferring context: 2B                                            0.0s
#  => [quepid-api-web internal] load build context                           0.0s
#  => => transferring context: 1.15kB                                        0.0s
#  => [quepid-api-web web 1/4] FROM docker.io/library/nginx:mainline-alpine  0.0s
#  => => resolve docker.io/library/nginx:mainline-alpine@sha256:8491795299c  0.0s
#  => [quepid-api-web app  1/13] FROM docker.io/library/python:3.12@sha256:  0.0s
#  => => resolve docker.io/library/python:3.12@sha256:f3396041c12dac446a6b8  0.0s
#  => CACHED [quepid-api-web app  2/13] WORKDIR /app                         0.0s
#  => CACHED [quepid-api-web app  3/13] RUN mkdir /tmp/app -p &&     chmod   0.0s
#  => CACHED [quepid-api-web app  4/13] RUN apt-get update                   0.0s
#  => CACHED [quepid-api-web app  5/13] RUN apt-get install -y python3-dev   0.0s
#  => CACHED [quepid-api-web app  6/13] RUN apt-get install -y libnss3 libn  0.0s
#  => CACHED [quepid-api-web app  7/13] COPY ./requirements.txt ./           0.0s
#  => CACHED [quepid-api-web app  8/13] RUN pip install -r requirements.txt  0.0s
#  => CACHED [quepid-api-web app  9/13] RUN playwright install chromium      0.0s
#  => CACHED [quepid-api-web app 10/13] COPY . ./                            0.0s
#  => CACHED [quepid-api-web app 11/13] RUN ./manage.py collectstatic --noi  0.0s
#  => CACHED [quepid-api-web app 12/13] RUN chown -R www-data:www-data .     0.0s
#  => CACHED [quepid-api-web app 13/13] RUN ln -snf /usr/share/zoneinfo/Eur  0.0s
#  => CACHED [quepid-api-web web 2/4] RUN apk add --no-cache tzdata          0.0s
#  => CACHED [quepid-api-web web 3/4] COPY --from=app /app/static /usr/shar  0.0s
#  => CACHED [quepid-api-web web 4/4] COPY docker/nginx.conf /etc/nginx/con  0.0s
#  => [quepid-api-web] exporting to image                                    0.0s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:c3d1afecde3f3e648f47b6a7b170670f4f025241  0.0s
#  => => exporting config sha256:7e05132cf6a698417480a28215e8c2295a278b1d88  0.0s
#  => => exporting attestation manifest sha256:1ab915bf1ad7d58c24c6b160c88c  0.0s
#  => => exporting manifest list sha256:31d6c84eaf1bedb9064e71ba25ff45b7b57  0.0s
#  => => naming to docker.io/frutik777/quepid-api-unofficial-web:latest      0.0s
#  => [quepid-api-app] exporting to image                                    0.1s
#  => => exporting layers                                                    0.0s
#  => => exporting manifest sha256:cbf6f19f9f838be6916f250b86aae276e7738f77  0.0s
#  => => exporting config sha256:5d995d9f5fe936792d7256dee0bba83ce241134d93  0.0s
#  => => exporting attestation manifest sha256:02c76f6e0efe6d578b5794af274b  0.0s
#  => => exporting manifest list sha256:b9b4b3c2030879be5c300e5bbb2574e1346  0.0s
#  => => naming to docker.io/frutik777/quepid-api-unofficial:latest          0.0s
#  => [quepid-api-web] resolving provenance for metadata file                0.0s
#  => [quepid-api-app] resolving provenance for metadata file                0.0s
# [+] Building 2/2
#  ✔ frutik777/quepid-api-unofficial-web:latest  Built                       0.0s
#  ✔ frutik777/quepid-api-unofficial:latest      Built                       0.0s

# %%
# !docker compose -f docker-compose.yml -f docker-compose-reranker.yml run quepid-api-quepid bin/rake db:migrate
# Out:
# [+] Running 0/1
#  ⠙ quepid-api-mysql Pulling                                                0.1s
# [+] Running 0/1
#  ⠹ quepid-api-mysql Pulling                                                0.2s
# [+] Running 0/1
#  ⠸ quepid-api-mysql Pulling                                                0.3s
# [+] Running 0/1
#  ⠼ quepid-api-mysql Pulling                                                0.4s
# [+] Running 0/1
#  ⠴ quepid-api-mysql Pulling                                                0.5s
# [+] Running 0/1
#  ⠦ quepid-api-mysql Pulling                                                0.6s
# [+] Running 0/1
#  ⠧ quepid-api-mysql Pulling                                                0.7s
# [+] Running 0/1
#  ⠇ quepid-api-mysql Pulling                                                0.8s
# [+] Running 0/1
#  ⠏ quepid-api-mysql Pulling                                                0.9s
# [+] Running 0/1
#  ⠋ quepid-api-mysql Pulling                                                1.0s
# [+] Running 1/1
#  ✔ quepid-api-mysql Pulled                                                 1.1s
# [+] Running 1/1
#  ✔ quepid-api-mysql Pulled                                                 1.1s
# WARN[0001] Found orphan containers ([quepid-api-unofficial-quepid-api-quepid-run-b31438de068e]) for this project. If you removed or renamed this service in your compose file, you can run this command with the --remove-orphans flag to clean it up.
# [+] Creating 2/2
#  ✔ Container quepid-api-unofficial-quepid-api-mysql-1  Running             0.0s
#  ✔ Container es-test                                   Running             0.0s
# [+] Running 0/1
#  ⠙ quepid-api-mysql Pulling                                                0.1s
# [+] Running 0/1
#  ⠹ quepid-api-mysql Pulling                                                0.2s
# [+] Running 0/1
#  ⠸ quepid-api-mysql Pulling                                                0.3s
# [+] Running 0/1
#  ⠼ quepid-api-mysql Pulling                                                0.4s
# [+] Running 0/1
#  ⠴ quepid-api-mysql Pulling                                                0.5s
# [+] Running 0/1
#  ⠦ quepid-api-mysql Pulling                                                0.6s
# [+] Running 0/1
#  ⠧ quepid-api-mysql Pulling                                                0.7s
# [+] Running 0/1
#  ⠇ quepid-api-mysql Pulling                                                0.8s
# [+] Running 0/1
#  ⠏ quepid-api-mysql Pulling                                                0.9s
# [+] Running 0/1
#  ⠋ quepid-api-mysql Pulling                                                1.0s
# [+] Running 1/1
#  ✔ quepid-api-mysql Pulled                                                 1.0s

# %%
# !docker compose -f docker-compose.yml -f docker-compose-reranker.yml run quepid-api-quepid bin/rake db:seed
# Out:
# [+] Running 0/1
#  ⠋ quepid-api-mysql Pulling                                                0.1s
# [+] Running 0/1
#  ⠙ quepid-api-mysql Pulling                                                0.2s
# [+] Running 0/1
#  ⠹ quepid-api-mysql Pulling                                                0.3s
# [+] Running 0/1
#  ⠸ quepid-api-mysql Pulling                                                0.4s
# [+] Running 0/1
#  ⠼ quepid-api-mysql Pulling                                                0.5s
# [+] Running 0/1
#  ⠴ quepid-api-mysql Pulling                                                0.6s
# [+] Running 0/1
#  ⠦ quepid-api-mysql Pulling                                                0.7s
# [+] Running 0/1
#  ⠧ quepid-api-mysql Pulling                                                0.8s
# [+] Running 0/1
#  ⠇ quepid-api-mysql Pulling                                                0.9s
# [+] Running 0/1
#  ⠏ quepid-api-mysql Pulling                                                1.0s
# [+] Running 1/1
#  ✔ quepid-api-mysql Pulled                                                 1.0s
# WARN[0001] Found orphan containers ([quepid-api-unofficial-quepid-api-quepid-run-524b65720c81 quepid-api-unofficial-quepid-api-quepid-run-b31438de068e]) for this project. If you removed or renamed this service in your compose file, you can run this command with the --remove-orphans flag to clean it up.
# [+] Creating 2/2
#  ✔ Container quepid-api-unofficial-quepid-api-mysql-1  Running             0.0s
#  ✔ Container es-test                                   Running             0.0s
# [+] Running 0/1
#  ⠋ quepid-api-mysql Pulling                                                0.1s
# [+] Running 0/1
#  ⠙ quepid-api-mysql Pulling                                                0.2s
# [+] Running 0/1
#  ⠹ quepid-api-mysql Pulling                                                0.3s
# [+] Running 0/1
#  ⠸ quepid-api-mysql Pulling                                                0.4s
# [+] Running 0/1
#  ⠼ quepid-api-mysql Pulling                                                0.5s
# [+] Running 0/1
#  ⠴ quepid-api-mysql Pulling                                                0.6s
# [+] Running 0/1
#  ⠦ quepid-api-mysql Pulling                                                0.7s
# [+] Running 0/1
#  ⠧ quepid-api-mysql Pulling                                                0.8s
# [+] Running 0/1
#  ⠇ quepid-api-mysql Pulling                                                0.9s
# [+] Running 1/1
#  ✔ quepid-api-mysql Pulled                                                 1.0s
# [+] Running 1/1
#  ✔ quepid-api-mysql Pulled                                                 1.0s

# %%
# !docker compose -f docker-compose.yml -f docker-compose-reranker.yml run quepid-api-quepid bundle exec thor user:create -a admin@example.com "Admin User" supersecret
# Out:
# [+] Running 0/1
#  ⠙ quepid-api-mysql Pulling                                                0.1s
# [+] Running 0/1
#  ⠹ quepid-api-mysql Pulling                                                0.2s
# [+] Running 0/1
#  ⠸ quepid-api-mysql Pulling                                                0.3s
# [+] Running 0/1
#  ⠼ quepid-api-mysql Pulling                                                0.4s
# [+] Running 0/1
#  ⠴ quepid-api-mysql Pulling                                                0.5s
# [+] Running 0/1
#  ⠦ quepid-api-mysql Pulling                                                0.6s
# [+] Running 0/1
#  ⠧ quepid-api-mysql Pulling                                                0.7s
# [+] Running 0/1
#  ⠇ quepid-api-mysql Pulling                                                0.8s
# [+] Running 0/1
#  ⠏ quepid-api-mysql Pulling                                                0.9s
# [+] Running 0/1
#  ⠋ quepid-api-mysql Pulling                                                1.0s
# [+] Running 0/1
#  ⠙ quepid-api-mysql Pulling                                                1.1s
# [+] Running 1/1
#  ✔ quepid-api-mysql Pulled                                                 1.1s
# WARN[0001] Found orphan containers ([quepid-api-unofficial-quepid-api-quepid-run-d6d886a971d0 quepid-api-unofficial-quepid-api-quepid-run-a851a012d7da]) for this project. If you removed or renamed this service in your compose file, you can run this command with the --remove-orphans flag to clean it up.
# [+] Creating 2/2
#  ✔ Container quepid-api-unofficial-quepid-api-mysql-1  Running             0.0s
#  ✔ Container es-test                                   Running             0.0s
# [+] Running 0/1
#  ⠋ quepid-api-mysql Pulling                                                0.1s
# [+] Running 0/1
#  ⠙ quepid-api-mysql Pulling                                                0.2s
# [+] Running 0/1
#  ⠹ quepid-api-mysql Pulling                                                0.3s
# [+] Running 0/1
#  ⠸ quepid-api-mysql Pulling                                                0.4s
# [+] Running 0/1
#  ⠼ quepid-api-mysql Pulling                                                0.5s
# [+] Running 0/1
#  ⠴ quepid-api-mysql Pulling                                                0.6s
# [+] Running 0/1
#  ⠦ quepid-api-mysql Pulling                                                0.7s
# [+] Running 0/1
#  ⠧ quepid-api-mysql Pulling                                                0.8s
# [+] Running 0/1
#  ⠇ quepid-api-mysql Pulling                                                0.9s
# [+] Running 0/1
#  ⠏ quepid-api-mysql Pulling                                                1.0s
# [+] Running 0/1
#  ⠋ quepid-api-mysql Pulling                                                1.1s
# [+] Running 1/1
#  ✔ quepid-api-mysql Pulled                                                 1.1s
# Creating a new user with email: admin@example.com, name: Admin User, password: supersecret.
# Marking user as administrator? true
# Success!

# %%
# !docker compose -f docker-compose.yml -f docker-compose-reranker.yml run quepid-api-quepid bundle exec thor user:add_api_key admin@example.com
# Out:
# [+] Running 0/1
#  ⠙ quepid-api-mysql Pulling                                                0.1s
# [+] Running 0/1
#  ⠹ quepid-api-mysql Pulling                                                0.2s
# [+] Running 0/1
#  ⠸ quepid-api-mysql Pulling                                                0.3s
# [+] Running 0/1
#  ⠼ quepid-api-mysql Pulling                                                0.4s
# [+] Running 0/1
#  ⠴ quepid-api-mysql Pulling                                                0.5s
# [+] Running 0/1
#  ⠦ quepid-api-mysql Pulling                                                0.6s
# [+] Running 0/1
#  ⠧ quepid-api-mysql Pulling                                                0.7s
# [+] Running 0/1
#  ⠇ quepid-api-mysql Pulling                                                0.8s
# [+] Running 0/1
#  ⠏ quepid-api-mysql Pulling                                                0.9s
# [+] Running 0/1
#  ⠋ quepid-api-mysql Pulling                                                1.0s
# [+] Running 0/1
#  ⠙ quepid-api-mysql Pulling                                                1.1s
# [+] Running 0/1
#  ⠹ quepid-api-mysql Pulling                                                1.2s
# [+] Running 0/1
#  ⠸ quepid-api-mysql Pulling                                                1.3s
# [+] Running 1/1
#  ✔ quepid-api-mysql Pulled                                                 1.4s
# [+] Running 1/1
#  ✔ quepid-api-mysql Pulled                                                 1.4s
# WARN[0001] Found orphan containers ([quepid-api-unofficial-quepid-api-quepid-run-93dff88d732f quepid-api-unofficial-quepid-api-quepid-run-fad94714351a quepid-api-unofficial-quepid-api-quepid-run-d6d886a971d0 quepid-api-unofficial-quepid-api-quepid-run-a851a012d7da]) for this project. If you removed or renamed this service in your compose file, you can run this command with the --remove-orphans flag to clean it up.
# [+] Creating 2/2
#  ✔ Container quepid-api-unofficial-quepid-api-mysql-1  Running             0.0s
#  ✔ Container es-test                                   Running             0.0s
# [+] Running 0/1
#  ⠙ quepid-api-mysql Pulling                                                0.1s
# [+] Running 0/1
#  ⠹ quepid-api-mysql Pulling                                                0.2s
# [+] Running 0/1
#  ⠸ quepid-api-mysql Pulling                                                0.3s
# [+] Running 0/1
#  ⠼ quepid-api-mysql Pulling                                                0.4s
# [+] Running 0/1
#  ⠴ quepid-api-mysql Pulling                                                0.5s
# [+] Running 0/1
#  ⠦ quepid-api-mysql Pulling                                                0.6s
# [+] Running 0/1
#  ⠧ quepid-api-mysql Pulling                                                0.7s
# [+] Running 0/1
#  ⠇ quepid-api-mysql Pulling                                                0.8s
# [+] Running 0/1
#  ⠏ quepid-api-mysql Pulling                                                0.9s
# [+] Running 0/1
#  ⠋ quepid-api-mysql Pulling                                                1.0s
# [+] Running 1/1
#  ✔ quepid-api-mysql Pulled                                                 1.1s
# Generating and adding API key for user with email: admin@example.com
# Success! API key generated and saved: c3ebbc65f9adb6097e1815ac7ec035ebf13acbc39ec7f4e04611f8971090e6b8

# %%
QUEPID_TOKEN = 'c3ebbc65f9adb6097e1815ac7ec035ebf13acbc39ec7f4e04611f8971090e6b8'  # past the token you created earlier

# %%
# !docker compose -f docker-compose.yml -f docker-compose-reranker.yml up

# %% [markdown]
# #### Services

# %% [markdown]
# After `docker compose up` you will have running instance of elasticsearch, quepid and quepid HTTP API (with a sandbox)
#
# - for api sandbox: http://localhost:8081/api/docs
# - for quepid: http://localhost:3000/

# %%
there is not reranker support (in openai api meaning) in ollama https://github.com/ollama/ollama/issues/3368

# %% [markdown]
# #### Config

# %%
QUEPID_AUTH = {
    "Authorization": f"Bearer {QUEPID_TOKEN}"
}

# %% [markdown]
# ### Python dependencis

# %%
# !pip install pandas requests tqdm
# Out:
# Requirement already satisfied: pandas in /Users/frutik/.pyenv/versions/3.12.9/lib/python3.12/site-packages (2.3.0)
# Requirement already satisfied: requests in /Users/frutik/.pyenv/versions/3.12.9/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: tqdm in /Users/frutik/.pyenv/versions/3.12.9/lib/python3.12/site-packages (4.67.1)
# Requirement already satisfied: numpy>=1.26.0 in /Users/frutik/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/frutik/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/frutik/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/frutik/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/frutik/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/frutik/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/frutik/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/frutik/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from requests) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /Users/frutik/.pyenv/versions/3.12.9/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import requests
import json

from tqdm import tqdm
import pandas as pd

# %% [markdown]
# ### Getting WANDS data

# %%
# !git clone https://github.com/wayfair/WANDS.git
# Out:
# fatal: destination path 'WANDS' already exists and is not an empty directory.

# %%
query_df = pd.read_csv("WANDS/dataset/query.csv", sep='\t')
query_df
# Out:
#      query_id                                              query  \
# 0           0                                        salon chair
# 1           1                                 smart coffee table
# 2           2                                           dinosaur
# 3           3                                  turquoise pillows
# 4           4                          chair and a half recliner
# ..        ...                                                ...
# 475       483                                        rustic twig
# 476       484  nespresso vertuo next premium by breville with...
# 477       485                                     pedistole sink
# 478       486                                54 in bench cushion
# 479       487                                         rack glass
#
#                   query_class
# 0              Massage Chairs
# 1    Coffee & Cocktail Tables
# 2             Kids Wall Décor
# 3              Accent Pillows
# 4                   Recliners
# ..                        ...
# 475     Faux Plants and Trees
# 476         Espresso Machines
# 477             Kitchen Sinks
# 478        Furniture Cushions
# 479            Candle Holders
#
# [480 rows x 3 columns]

# %%
product_df = pd.read_csv("WANDS/dataset/product.csv", sep='\t')
product_df
# Out:
#        product_id                                       product_name  \
# 0               0                            solid wood platform bed
# 1               1                        all-clad 7 qt . slow cooker
# 2               2            all-clad electrics 6.5 qt . slow cooker
# 3               3       all-clad all professional tools pizza cutter
# 4               4  baldwin prestige alcott passage knob with roun...
# ...           ...                                                ...
# 42989       42989  malibu pressure balanced diverter fixed shower...
# 42990       42990              emmeline 5 piece breakfast dining set
# 42991       42991                      maloney 3 piece pub table set
# 42992       42992           fletcher 27.5 '' wide polyester armchair
# 42993       42993                            griffin 29 '' bar stool
#
#                              product_class  \
# 0                                     Beds
# 1                             Slow Cookers
# 2                             Slow Cookers
# 3             Slicers, Peelers And Graters
# 4                               Door Knobs
# ...                                    ...
# 42989                        Shower Panels
# 42990                    Dining Table Sets
# 42991                    Dining Table Sets
# 42992  Teen Lounge Furniture|Accent Chairs
# 42993                           Bar Stools
#
#                                       category hierarchy  \
# 0      Furniture / Bedroom Furniture / Beds & Headboa...
# 1      Kitchen & Tabletop / Small Kitchen Appliances ...
# 2      Kitchen & Tabletop / Small Kitchen Appliances ...
# 3                             Browse By Brand / All-Clad
# 4      Home Improvement / Doors & Door Hardware / Doo...
# ...                                                  ...
# 42989  Home Improvement / Bathroom Remodel & Bathroom...
# 42990  Furniture / Kitchen & Dining Furniture / Dinin...
# 42991  Furniture / Kitchen & Dining Furniture / Dinin...
# 42992  Furniture / Living Room Furniture / Chairs & S...
# 42993  Furniture / Kitchen & Dining Furniture / Bar F...
#
#                                      product_description  \
# 0      good , deep sleep can be quite difficult to ha...
# 1      create delicious slow-cooked meals , from tend...
# 2      prepare home-cooked meals on any schedule with...
# 3      this original stainless tool was designed to c...
# 4      the hardware has a rich heritage of delivering...
# ...                                                  ...
# 42989  the malibu pressure balanced diverter fixed sh...
# 42990                                                NaN
# 42991  this pub table set includes 1 counter height t...
# 42992  bring iconic , modern style to your space in a...
# 42993  this set of two barstools features a minimalis...
#
#                                         product_features  rating_count  \
# 0      overallwidth-sidetoside:64.7|dsprimaryproducts...          15.0
# 1      capacityquarts:7|producttype : slow cooker|pro...         100.0
# 2      features : keep warm setting|capacityquarts:6....         208.0
# 3      overallwidth-sidetoside:3.5|warrantylength : l...          69.0
# 4      compatibledoorthickness:1.375 '' |countryofori...          70.0
# ...                                                  ...           ...
# 42989  producttype : shower panel|spraypattern : rain...           3.0
# 42990  basematerialdetails : steel| : gray wood|ofhar...        1314.0
# 42991  additionaltoolsrequirednotincluded : power dri...          49.0
# 42992  legmaterialdetails : rubberwood|backheight-sea...        1746.0
# 42993  distancebetweenfloorandfootrest:7.5|dssecondar...          20.0
#
#        average_rating  review_count
# 0                 4.5          15.0
# 1                 2.0          98.0
# 2                 3.0         181.0
# 3                 4.5          42.0
# 4                 5.0          42.0
# ...               ...           ...
# 42989             4.5           2.0
# 42990             4.5         864.0
# 42991             4.0          41.0
# 42992             4.5        1226.0
# 42993             4.5          20.0
#
# [42994 rows x 9 columns]

# %%
labels_df = pd.read_csv("WANDS/dataset/label.csv", sep='\t')
labels_df
# Out:
#             id  query_id  product_id       label
# 0            0         0       25434       Exact
# 1            1         0       12088  Irrelevant
# 2            2         0       42931       Exact
# 3            3         0        2636       Exact
# 4            4         0       42923       Exact
# ...        ...       ...         ...         ...
# 233443  234010       478       15439     Partial
# 233444  234011       478         451     Partial
# 233445  234012       478       30764  Irrelevant
# 233446  234013       478       16796     Partial
# 233447  234014       486       30764     Partial
#
# [233448 rows x 4 columns]

# %% [markdown]
# ## Set up Elasticsearch

# %% [markdown]
# ### Create index

# %%
mapping = {
  "mappings": {
    "properties": {
      "name": {
        "type": "text"
      },
      "class": {
        "type": "text"
      },
      "categories": {
        "type": "text"
      },
      "description": {
        "type": "text"
      }

    }
  }
  }

# %%
index = requests.put(
    'http://localhost:9200/product-0',
    json=mapping
)
index.json()
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'product-0'}

# %% [markdown]
# ### Index products

# %%
def index_record(index, id, name, description, product_type, categories):
    if id and name and description:
        try:
            return requests.post(
                f"http://localhost:9200/{index}/_doc/{id}",
                json={
                    'name': name,
                    'class': product_type,
                    'categories': categories,
                    'description': description
                }
            )
        except:
            pass

# %%
for index, row in tqdm(product_df.iterrows(), total=len(product_df)):
    _ = index_record('product-0', row['product_id'], row['product_name'], row['product_description'], row['product_class'], row['category hierarchy'])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 42994/42994 [02:27<00:00, 292.20it/s]

# %%
response = requests.post(
    "http://localhost:9200/product-0/_search",
    json={
        "size": 0,
        "track_total_hits": True
    }
)
response.json()
# Out:
# {'took': 164,
#  'timed_out': False,
#  'terminated_early': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 33364, 'relation': 'eq'},
#   'max_score': None,
#   'hits': []}}

# %% [markdown]
# ## Baseline test

# %%
QUEPID_AUTH
# Out:
# {'Authorization': 'Bearer 5d09bea0983f94833d87efbc24075d71dfa89aa306b8b24f3c9269c111f524be'}

# %%
# Create team

team = requests.post(
    'http://localhost:8081/api/teams/', 
    headers = QUEPID_AUTH,
    json={
        "name": "wands"
    }   
)

team = team.json()
team
# Out:
# {'detail': 'Unauthorized'}

# %%
add category, brand, other. test suggestion from doug about name scores

# %%
# Create search endpoint

endpoint = requests.post(
    'http://localhost:8081/api/search_endpoints/', 
    headers = QUEPID_AUTH,
    json={
        "name": "wands",
        "endpoint_url": "http://quepid-api-elasticsearch:9200/product-0/_search",
        "search_engine": "es",
        "api_method": "POST",
        "proxy_requests": 1,   
    }   
)

endpoint = endpoint.json()
endpoint
# Out:
# {'id': 1,
#  'name': 'wands',
#  'owner': 1,
#  'search_engine': 'es',
#  'endpoint_url': 'http://quepid-api-elasticsearch:9200/product-0/_search',
#  'api_method': 'POST',
#  'custom_headers': None,
#  'archived': 0,
#  'created_at': '2026-01-04T16:20:30.274Z',
#  'updated_at': '2026-01-04T16:20:30.274Z',
#  'basic_auth_credential': None,
#  'mapper_code': None,
#  'proxy_requests': 1,
#  'options': None}

# %%
# list scorers
scorers = requests.get(
    'http://localhost:8081/api/scorers/', 
    headers = QUEPID_AUTH
)
{s['id']: s['name'] for s in scorers.json()['items']}
# Out:
# {1: 'nDCG@10',
#  2: 'DCG@10',
#  3: 'CG@10',
#  4: 'P@10',
#  5: 'AP@10',
#  6: 'RR@10',
#  7: 'ERR@10'}

# %%
# Create cases

search_query_boosted = {
  "retriever": {
    "standard": {
      "query": {
        "multi_match": {
          "query": '#$query##',
          "fields": ["name^2", "description"]
        }
      }
    }
  }
}


baseline_case = requests.post(
    'http://localhost:8081/api/case/', 
    headers = QUEPID_AUTH,
    json={
        "name": "baseline",
        "scorer_id": 1,
        "book_id": 0,
        "search_endpoint_id": endpoint.get('id'),
        "search_query": json.dumps(search_query_boosted)
    }   
)

baseline_case = baseline_case.json()
baseline_case
# Out:
# {'id': 1,
#  'case_name': 'baseline',
#  'last_try_number': 1,
#  'owner': 1,
#  'archived': 0,
#  'scorer_id': 1,
#  'created_at': '2026-01-04T16:27:42.110Z',
#  'updated_at': '2026-01-04T16:27:42.110Z',
#  'book_id': None,
#  'public': None,
#  'options': None,
#  'nightly': 1}

# %% [markdown]
# ### Load queries and Judgements

# %%
# utils

def add_query(case, query):
    quepid_query = requests.post(
        f'http://localhost:8081/api/query/{case.get("id")}/', 
        headers = QUEPID_AUTH,
        json={
            "query_text": query
        }   
    )
    if quepid_query.status_code == 200:
        return quepid_query.json() 


def add_label(query_id, doc_id, label):
    # print([query, doc_id, label])
    return requests.post(
        f'http://localhost:8081/api/rating/query/{query_id}/rating/', 
        headers = QUEPID_AUTH,
        json={
            "doc_id": str(doc_id),
            "rating": label_to_rating(label)
        }   
    )


def label_to_rating(label):
    if label == 'Partial':
        return 2
    if label == 'Exact':
        return 3
    return 0


def add_labels(quepid_query, query_labels):
    for _, label in query_labels.iterrows():
        add_label(quepid_query, label['product_id'], label['label'])

# %%
for index, row in tqdm(query_df.iterrows(), total=len(query_df)):
    query_labels_df = labels_df[labels_df['query_id'] == row['query_id']]
    if quepid_query := add_query(baseline_case, row['query']):
        add_labels(quepid_query.get('id'), query_labels_df)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 480/480 [26:30<00:00,  3.31s/it]

# %% [markdown]
# 0.14

# %% [markdown]
# ## Simple rerank test

# %% [markdown]
# ### Elasticsearch reranking endpoint

# %%
inference_endpoint = requests.put(
    "http://localhost:9200/_inference/rerank/qwen3-rerank",
    json={
        "service": "custom",
        "service_settings": {
            "url": "http://llamacpp-reranker:8080/v1/rerank",
            "headers": {
                "Content-Type": "application/json"
            },
            "request": "{\"query\":${query},\"documents\":${input},\"top_n\": 100}",
            "response": {
                "json_parser": {
                    "reranked_index": "$.results[*].index",
                    "relevance_score": "$.results[*].relevance_score"
                }
            }
        }
    }
)

inference_endpoint.json()
# Out:
# {'inference_id': 'qwen3-rerank',
#  'task_type': 'rerank',
#  'service': 'custom',
#  'service_settings': {'url': 'http://llamacpp-reranker:8080/v1/rerank',
#   'headers': {'Content-Type': 'application/json'},
#   'request': '{"query":${query},"documents":${input},"top_n": 100}',
#   'response': {'json_parser': {'relevance_score': '$.results[*].relevance_score',
#     'reranked_index': '$.results[*].index'}},
#   'input_type': {'translation': {}, 'default': ''},
#   'rate_limit': {'requests_per_minute': 10000},
#   'batch_size': 10}}

# %% [markdown]
# ### Set up the case

# %%
# Create cases

search_query_simple_rerank = {
   "retriever":{
      "text_similarity_reranker":{
         "retriever":{
            "standard":{
               "query":{
                  "multi_match":{
                     "query":"#$query##",
                     "fields":[
                        "name^2",
                        "description"
                     ]
                  }
               }
            }
         },
         "field":"name",
         "inference_id":"qwen3-rerank",
         "inference_text":"#$query##",
         "rank_window_size":100,
         "min_score":0.5
      }
   }
}

simple_rerank_case = requests.post(
    'http://localhost:8081/api/case/', 
    headers = QUEPID_AUTH,
    json={
        "name": "simple_rerank",
        "scorer_id": 1,
        "book_id": 0,
        "search_endpoint_id": endpoint.get('id'),
        "search_query": json.dumps(search_query_simple_rerank)
    }   
)

simple_rerank_case = simple_rerank_case.json()
simple_rerank_case
# Out:
# {'id': 2,
#  'case_name': 'simple_rerank',
#  'last_try_number': 1,
#  'owner': 1,
#  'archived': 0,
#  'scorer_id': 1,
#  'created_at': '2026-01-04T17:20:27.359Z',
#  'updated_at': '2026-01-04T17:20:27.359Z',
#  'book_id': None,
#  'public': None,
#  'options': None,
#  'nightly': 1}

# %%
for index, row in tqdm(query_df.iterrows(), total=len(query_df)):
    query_labels_df = labels_df[labels_df['query_id'] == row['query_id']]
    if quepid_query := add_query(simple_rerank_case, row['query']):
        add_labels(quepid_query.get('id'), query_labels_df)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████| 480/480 [36:31<00:00,  4.57s/it]

# %% [markdown]
# RESULT

# %% [markdown]
# ## TODO
#
# - instructions
# - dedicated rerank filed

# %% [markdown]
# ### Search in data

# %% [markdown]
# llama.cpp is a low-level inference engine, while Ollama is a user-friendly product that builds on top of engines like llama.cpp to make running LLMs easy.
#
# curl -X POST  -H "Content-Type: application/json" http://localhost:8080/v1/rerank  -d '{
#     "query": "Sample query",
#     "documents": [
#         "Sample document 1",
#         "Sample document 2"
#     ],
#     "model": "dengcao/Qwen3-Reranker-4B-GGUF:Q4_K_M"
#   }'
#
# docker compose exec llamacpp-server /bin/bash
# root@6c05a8b26cf8:/app# ./llama-server -hf dengcao/Qwen3-Reranker-4B-GGUF:Q4_K_M
#
#
#
# q4_k_m vs q5_k_m (for Qwen3-Reranker-4B GGUF / llama.cpp)
#
# Rule of thumb:
#
# Q4_K_M = best default (speed + memory + solid quality)
#
# Q5_K_M = noticeably more faithful reranking when you can spare RAM/latency
#
# This matches how the llama.cpp community generally buckets the “recommended” K-quants (Q4_K_M
#
# https://medium.com/%40michael.hannecke/gguf-optimization-a-technical-deep-dive-for-practitioners-ce84c8987944
#
# Memory / size impact (your exact model family)
#
# For Qwen3-Reranker-4B GGUF, typical files are roughly:
#
# Q4_K_M ~ 2.5 GB
#
# Q5_K_M ~ 2.9 GB
#
# So you’re paying ~+0.4 GB disk, and also a bit more RAM at runtime.
# Hugging Face
# +1
#
# Latency impact (what to expect)
#
# Usually:
#
# Q5_K_M is a bit slower than Q4_K_M (more bits → more bandwidth/compute), but not dramatically.
#
# On CPU-heavy setups, you’ll notice it more than on GPU.
#
# (Exact delta depends on your CPU, threads, batch sizes, and N_PARALLEL.)
#
#
# Which one you should use
# Pick Q4_K_M if:
#
# you rerank lots of queries per second
#
# you do top-100 rerank frequently
#
# you’re memory-constrained (containers, small nodes)
#
# you want “good enough” and predictable
#
# This is widely considered the “safe default.”
# Medium
# +1
#
# Pick Q5_K_M if:
#
# you care about last-mile ranking quality
#
# your candidates are very similar (typical e-commerce: same product with slight variations)
#
# you rerank only top-20 / top-50 so compute is manageable
#
# you can afford ~+15–25% extra memory + some latency
#
# Model publishers for Qwen3 GGUF variants commonly recommend Q5_K_M as “very low quality loss.”
# Hugging Face
# +1
#
# Practical recommendation for your setup (e-commerce reranking)
#
# If this is online reranking (user-facing latency): start with Q4_K_M.
#
# If this is offline evaluation / improving nDCG: use Q5_K_M (or even Q6_K if you don’t care about RAM).
#
# If you want, paste your typical rerank payload sizes (avg doc length, N docs per call, QPS), and I’ll tell you which quant will likely win for your constraints.

# %% [markdown]
# r = requests.post('http://localhost:9200/product-1/_search',
# json={
#   "knn": {
#     "field": "name_embedding",
#     "query_vector_builder": {
#       "text_embedding": {
#         "model_id": "qwen3-embeddings",
#         "model_text": "dinosaur"
#       }
#     },
#     "k": 10,
#     "num_candidates": 300
#   },
#   "_source": "name"
# })
#
# r.json()

# %%
https://chatgpt.com/share/695a4995-8dcc-8001-b543-a40ca33c4e43

<Instruct>: Given a web search query, retrieve relevant passages that answer the query  
<Query>: [User’s query]  
<Document>: [Candidate text]

# %%
 Q4_1, Q5_0
https://medium.com/%40michael.hannecke/gguf-optimization-a-technical-deep-dive-for-practitioners-ce84c8987944
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 Q4_1, Q5_0
#
# NameError: name 'Q4_1' is not defined

# %%
POST _search
{
  "retriever": {
    "text_similarity_reranker": {
      "retriever": {
        "standard": {
          "query": {
            "match": {
              "text": "How often does the moon hide the sun?"
            }
          }
        }
      },
      "field": "text",
      "inference_id": "my-elastic-rerank",
      "inference_text": "How often does the moon hide the sun?",
      "rank_window_size": 100,
      "min_score": 0.5
    }
  }
}
# Out:
#   Cell In[40], line 1
#     POST _search
#          ^
# SyntaxError: invalid syntax

# %%
requests.get(
    'http://localhost:8081/api/case/1/', 
    headers = AUTH   
).json()
# Out:
# {'id': 1,
#  'case_name': 'wands',
#  'last_try_number': 1,
#  'owner': 1,
#  'archived': 0,
#  'scorer_id': 1,
#  'created_at': '2025-08-14T14:03:37Z',
#  'updated_at': '2025-08-14T14:03:37Z',
#  'book_id': None,
#  'public': None,
#  'options': None,
#  'nightly': 1}

# %%
try to push it to the limits

# %% [markdown]
# what latest score is?

# %% [markdown]
# ![Title](quepid-wands.png)

# %%
def search_query(query='#$query##'):
    return {
      "knn": {
        "field": "name_embedding",
        "query_vector_builder": {
          "text_embedding": {
            "model_id": "qwen3-embeddings",
            "model_text": query
          }
        },
        "k": 10,
        "num_candidates": 300
      },
      "_source": "name"
    }


def search(index, query, instruction=None):
    if instruction:
        query = instruction.format(query=query)
    print(query)
    response = requests.post(
        f"http://localhost:9200/{index}/_search",
        json=search_query(query)
    )
    return response.json()

# %%
instruction = "Instruct: Embed the product title for e-commerce search\nProduct name: {query}"
# print(search('product-1', 'dinosaur'))
# print(search('product-2', 'dinosaur', instruction))
print(search('product-1', 'men shoes 43'))
print(search('product-2', 'men shoes 43', instruction))
# Out:
# men shoes 43
# {'took': 343, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 10, 'relation': 'eq'}, 'max_score': 0.86428356, 'hits': [{'_index': 'product-1', '_id': '22396', '_score': 0.86428356, '_source': {'name': '45 pair shoe rack'}}, {'_index': 'product-1', '_id': '39396', '_score': 0.84891415, '_source': {'name': 'closet organizer 45 pair shoe storage cabinet'}}, {'_index': 'product-1', '_id': '6996', '_score': 0.84537125, '_source': {'name': '30 pair shoe rack'}}, {'_index': 'product-1', '_id': '40956', '_score': 0.84462166, '_source': {'name': '3 pair shoe storage'}}, {'_index': 'product-1', '_id': '29881', '_score': 0.84303, '_source': {'name': 'fit and stylish shoe closet shoes - print'}}, {'_index': 'product-1', '_id': '36863', '_score': 0.84227943, '_source': {'name': '45 pair shoe storage cabinet'}}, {'_index': 'product-1', '_id': '28414', '_score': 0.84218884, '_source': {'name': 'rebrilliant 40 pair stackable shoe rack'}}, {'_index': 'product-1', '_id': '6994', '_score': 0.84210587, '_source': {'name': '32 pair shoe rack'}}, {'_index': 'product-1', '_id': '3965', '_score': 0.84195805, '_source': {'name': '48 pair shoe rack'}}, {'_index': 'product-1', '_id': '22395', '_score': 0.8403168, '_source': {'name': '36 pair shoe rack'}}]}}
# Instruct: Embed the product title for e-commerce search
# Product name: men shoes 43
# {'took': 668, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 10, 'relation': 'eq'}, 'max_score': 0.6932788, 'hits': [{'_index': 'product-2', '_id': '1', '_score': 0.6932788, '_source': {'name': 'all-clad 7 qt . slow cooker'}}, {'_index': 'product-2', '_id': '2', '_score': 0.6932788, '_source': {'name': 'all-clad electrics 6.5 qt . slow cooker'}}, {'_index': 'product-2', '_id': '3', '_score': 0.6932788, '_source': {'name': 'all-clad all professional tools pizza cutter'}}, {'_index': 'product-2', '_id': '4', '_score': 0.6932788, '_source': {'name': 'baldwin prestige alcott passage knob with round rosette'}}, {'_index': 'product-2', '_id': '5', '_score': 0.6932788, '_source': {'name': "vogan 33 '' single bathroom vanity"}}, {'_index': 'product-2', '_id': '6', '_score': 0.6932788, '_source': {'name': "vogelsang 48 '' single bathroom vanity"}}, {'_index': 'product-2', '_id': '7', '_score': 0.6932788, '_source': {'name': "36 '' single bathroom vanity"}}, {'_index': 'product-2', '_id': '8', '_score': 0.6932788, '_source': {'name': 'erith obliqui urn'}}, {'_index': 'product-2', '_id': '9', '_score': 0.6932788, '_source': {'name': "vezina 65 '' rolled arm chesterfield loveseat"}}, {'_index': 'product-2', '_id': '10', '_score': 0.6932788, '_source': {'name': 'trestle coffee table'}}]}}
